# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/raw/time_series_60min_singleindex.csv')

# %%
data.duplicated(subset='utc_timestamp').sum()
# Out:
# np.int64(0)

# %%
data.head()
# Out:
#           utc_timestamp        cet_cest_timestamp  \
# 0  2014-12-31T23:00:00Z  2015-01-01T00:00:00+0100
# 1  2015-01-01T00:00:00Z  2015-01-01T01:00:00+0100
# 2  2015-01-01T01:00:00Z  2015-01-01T02:00:00+0100
# 3  2015-01-01T02:00:00Z  2015-01-01T03:00:00+0100
# 4  2015-01-01T03:00:00Z  2015-01-01T04:00:00+0100
#
#    AT_load_actual_entsoe_transparency  AT_load_forecast_entsoe_transparency  \
# 0                                 NaN                                   NaN
# 1                              5946.0                                6701.0
# 2                              5726.0                                6593.0
# 3                              5347.0                                6482.0
# 4                              5249.0                                6454.0
#
#    AT_price_day_ahead  AT_solar_generation_actual  \
# 0                 NaN                         NaN
# 1                35.0                         NaN
# ...

# %%
germany_data = data['DE_load_actual_entsoe_transparency']

# %%
germany_data.head()
# Out:
# 0        NaN
# 1    41151.0
# 2    40135.0
# 3    39106.0
# 4    38765.0
# Name: DE_load_actual_entsoe_transparency, dtype: float64

# %%
germany_data.isna().sum()
# Out:
# np.int64(1)

# %%
germany_data = germany_data.iloc[1:]
germany_data.isna().sum()
# Out:
# np.int64(0)

# %%
germany_data.describe()
# Out:
# count    50399.000000
# mean     55492.753110
# std      10015.326661
# min      31307.000000
# 25%      47106.000000
# 50%      55092.000000
# 75%      64309.500000
# max      77549.000000
# Name: DE_load_actual_entsoe_transparency, dtype: float64

# %%
germany_data.info(0)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 50399 entries, 2 to 50400
# dtypes: float64(1)
# memory usage: 393.9 KB

# %%
germany_data.shape
# Out:
# 50396    57559.0
# 50397    54108.0
# 50398    49845.0
# 50399    46886.0
# 50400    45461.0
# Name: DE_load_actual_entsoe_transparency, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.plot(germany_data)
plt.show()
